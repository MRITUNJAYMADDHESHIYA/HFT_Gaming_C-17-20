# %%
import pandas as pd

# %%
INVEST_FILE = "C:/Users/Mritunjay Maddhesiya/OneDrive/Desktop/C++HFT/Portfolio_Constraint/data/assignment_investment_rules.csv"
SECTOR_FILE = "C:/Users/Mritunjay Maddhesiya/OneDrive/Desktop/C++HFT/Portfolio_Constraint/data/assignment_sector_data.csv"
MCAP_FILE = "C:/Users/Mritunjay Maddhesiya/OneDrive/Desktop/C++HFT/Portfolio_Constraint/data/assignment_mcap.csv"

invest_df = pd.read_csv(INVEST_FILE) # investment strategy
sector_df = pd.read_csv(SECTOR_FILE) # sector and industory
mcap_df = pd.read_csv(MCAP_FILE)     # market capitaliztion

# %%
print(invest_df.columns)
print(mcap_df.columns)
print(sector_df.columns)
# Out:
# Index(['strat_name', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022'],
#       dtype='object')
# Index(['CO_NAME', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')
# Index(['CO_NAME', 'Cline_Code', 'Company Long Name', 'Sector', 'Industry'], dtype='object')

# %%
print(invest_df.head(1))
# Out:
#                                           strat_name  1997  1998 1999 2000  \
# 0  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN   []   []
#
#                                                 2001  \
# 0  ['Hero Motocorp', 'Reliance Industr', "Dr Redd...
#
#                                                 2002  \
# 0  ['Hero Motocorp', 'Pfizer', 'Reliance Industr'...
#
#                                                 2003  \
# 0  ['Hero Motocorp', 'Piramal Enterp.', 'Reliance...
#
#                                                 2004  \
# 0  ['Hero Motocorp', 'Reliance Industr', 'Vedanta...
#
#                                                 2005  ...  \
# 0  ['Graphite India', 'Eicher Motors', 'Hero Moto...  ...
#
#                                                 2013  \
# 0  ['Balkrishna Inds', 'Bata India', 'Bombay Burm...
#
#                                                 2014  \
# 0  ['Atul', 'Balkrishna Inds', 'Bata India', 'Bom...
#
#                                                 2015  \
# 0  ['Atul', 'Bata India', 'Bombay Burmah', 'Brita...
#
#                                                 2016  \
# 0  ['Bombay Burmah', 'Britannia Inds.', 'CESC', '...
#
#                                                 2017  \
# 0  ['Bombay Burmah', 'Britannia Inds.', 'J B Chem...
#
#                                                 2018  \
# 0  ['Bombay Burmah', 'Britannia Inds.', 'Whirlpoo...
#
#                                                 2019  \
# 0  ['Ashok Leyland', 'Bombay Burmah', 'Britannia ...
#
#                                                 2020  \
# 0  ['Safari Inds.', 'Bharat Rasayan', 'Bajaj Fina...
#
#                                                 2021  \
# 0  ['Hil Ltd', 'Alkyl Amines', 'Acrysil', 'Gufic ...
#
#                                                 2022
# 0  ['J B Chem & Pharm', 'Alkyl Amines', 'Hindusta...
#
# [1 rows x 27 columns]
