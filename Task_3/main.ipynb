# %%
import pandas as pd

# %%
df = {
    "timestamp": [
        "2026-01-02 01:00:00",
        "2026-01-02 02:00:00",
        "2026-01-02 03:00:00",
        "2026-01-02 04:00:00",
        "2026-01-02 05:00:00",
        "2026-01-01 00:00:00",
        "2026-01-01 01:00:00",
        "2026-01-01 02:00:00",
        "2026-01-01 03:00:00",
        "2026-01-01 04:00:00",
        "2026-01-01 04:00:00",
        "2026-01-01 06:00:00",
        "2026-01-01 07:00:00",
        "2026-01-01 08:00:00",
        "2026-01-01 09:00:00",
        "2026-01-01 10:00:00",
        "2026-01-01 11:00:00",
        "2026-01-01 12:00:00",
        "2026-01-01 13:00:00",
        "2026-01-01 14:00:00",
        "2026-01-01 15:00:00",
        "2026-01-01 16:00:00",
        "2026-01-01 17:00:00",
        "2026-01-01 18:00:00",
        "2026-01-01 19:00:00",
        "2026-01-01 20:00:00",
        "2026-01-01 21:00:00",
        "2026-01-01 22:00:00",
        "2026-01-01 23:00:00",
        "2026-01-02 00:00:00",
        "2026-01-02 01:00:00",
        "2026-01-02 02:00:00",
        "2026-01-02 03:00:00",
        "2026-01-02 04:00:00",
        "2026-01-02 05:00:00",
        "2026-01-01 08:00:00",
        "2026-01-01 00:00:00",
        "2026-01-01 01:00:00",
        "2026-01-01 02:00:00",
        "2026-01-01 03:00:00",
        "2026-01-01 05:00:00",
        "2026-01-01 05:00:00",
        "2026-01-01 06:00:00",
        "2026-01-01 07:00:00",
        "2026-01-01 08:00:00",
        "2026-01-01 09:00:00",
        "2026-01-01 10:00:00",
        "2026-01-01 11:00:00",
        "2026-01-01 13:00:00",
        "2026-01-01 14:00:00",
        "2026-01-01 15:00:00",
        "2026-01-01 16:00:00",
        "2026-01-01 17:00:00",
        "2026-01-01 18:00:00",
        "2026-01-01 19:00:00",
        "2026-01-01 20:00:00",
        "2026-01-01 21:00:00",
        "2026-01-01 22:00:00",
        "2026-01-01 23:00:00",
        "2026-01-02 00:00:00",
    ],
    "symbol": [
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "BTCUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "ETHUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "ETHUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
        "BTCUSDT",
    ],
    "close": [
        43625.0,
        43650.0,
        43675.0,
        43750.0,
        43725.0,
        2300.5,
        2301.5,
        2303.0,
        2304.5,
        2306.0,
        43100.0,
        2309.0,
        2310.5,
        2312.0,
        2313.5,
        2315.5,
        2316.5,
        2318.0,
        2319.5,
        2321.0,
        2323.0,
        2324.0,
        2325.5,
        2327.0,
        2328.5,
        2330.5,
        2331.5,
        2333.0,
        2334.5,
        2336.0,
        2338.0,
        2339.0,
        2340.5,
        2342.0,
        2343.5,
        2312.25,
        43050.0,
        43025.0,
        43050.0,
        43075.0,
        2308.0,
        43125.0,
        43150.0,
        43225.0,
        43200.0,
        43225.0,
        43250.0,
        43275.0,
        43325.0,
        43400.0,
        43375.0,
        43400.0,
        43425.0,
        43450.0,
        43475.0,
        43500.0,
        43575.0,
        43550.0,
        43575.0,
        43600.0,
    ],
}

# %%
data = pd.DataFrame(df)

# %%
print(data.head(5))
print(data.tail(5))
# Out:
#              timestamp   symbol    close
# 0  2026-01-02 01:00:00  BTCUSDT  43625.0
# 1  2026-01-02 02:00:00  BTCUSDT  43650.0
# 2  2026-01-02 03:00:00  BTCUSDT  43675.0
# 3  2026-01-02 04:00:00  BTCUSDT  43750.0
# 4  2026-01-02 05:00:00  BTCUSDT  43725.0
#               timestamp   symbol    close
# 55  2026-01-01 20:00:00  BTCUSDT  43500.0
# 56  2026-01-01 21:00:00  BTCUSDT  43575.0
# 57  2026-01-01 22:00:00  BTCUSDT  43550.0
# 58  2026-01-01 23:00:00  BTCUSDT  43575.0
# 59  2026-01-02 00:00:00  BTCUSDT  43600.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  60 non-null     object
#  1   symbol     60 non-null     object
#  2   close      60 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ KB

# %%
df['time'] = pd.to_datetime(data['timestamp'])

df['time'] = pd.set_index('timestamp', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 df['time'] = pd.to_datetime(data['timestamp'])
# ----> 2 df['time'] = pd.set_index('timestamp', inplace=True)
#       3 df
#
# AttributeError: module 'pandas' has no attribute 'set_index'

# %%
class car:
    def engin(self):
        pass

class bmw(car):
    def price(self):
        pass
